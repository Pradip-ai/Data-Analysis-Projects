# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

data = pd.read_csv(r'D:\Data Visualization\vgsales.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.shape
# Out:
# (16598, 11)

# %%
data.values
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16598, step=1)

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
data['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
data.nunique()
# Out:
# Rank            16598
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64

# %%
data.count()
# Out:
# Rank            16598
# Name            16598
# Platform        16598
# Year            16327
# Genre           16598
# Publisher       16540
# NA_Sales        16598
# EU_Sales        16598
# JP_Sales        16598
# Other_Sales     16598
# Global_Sales    16598
# dtype: int64

# %%
data['Genre'].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
data.nunique()
# Out:
# Rank            16598
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64

# %%
data['Name'].nunique()
# Out:
# 11493

# %%
data['Name'].unique()
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'Plushees', 'Woody Woodpecker in Crazy Castle 5', 'Know How 2'],
#       dtype=object)

# %%
data.Name.value_counts()
# Out:
# Need for Speed: Most Wanted                12
# Ratatouille                                 9
# FIFA 14                                     9
# LEGO Marvel Super Heroes                    9
# Madden NFL 07                               9
#                                            ..
# Ar tonelico Qoga: Knell of Ar Ciel          1
# Galaga: Destination Earth                   1
# Nintendo Presents: Crossword Collection     1
# TrackMania: Build to Race                   1
# Know How 2                                  1
# Name: Name, Length: 11493, dtype: int64

# %%
data.head(2)
data[data.Name =='Mario Kart Wii']
# Out:
#    Rank            Name Platform    Year   Genre Publisher  NA_Sales  \
# 2     3  Mario Kart Wii      Wii  2008.0  Racing  Nintendo     15.85
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 2     12.88      3.79         3.31         35.82

# %%
#groupby

data.groupby('Platform')

# %%
data.head(2)
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24

# %%
data[data['Global_Sales'] == 82.74] #
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  ...    0.1   0.09   0.08   0.07   0.06   0.05  \
# 0      3.77         8.46  ...  82.74  82.74  82.74  82.74  82.74  82.74
#
#     0.04   0.03   0.02   0.01
# 0  82.74  82.74  82.74  82.74
#
# [1 rows x 634 columns]

# %%
#Null values in the data

# %%
data.isnull().sum()
# Out:
# Rank          0
# Name          0
# Platform      0
# Year        271
# Genre         0
#            ...
# 0.05          0
# 0.04          0
# 0.03          0
# 0.02          0
# 0.01          0
# Length: 634, dtype: int64

# %%
data.notnull().sum()
# Out:
# Rank        16598
# Name        16598
# Platform    16598
# Year        16327
# Genre       16598
#             ...
# 0.05        16598
# 0.04        16598
# 0.03        16598
# 0.02        16598
# 0.01        16598
# Length: 634, dtype: int64

# %%
#Change the column name:
data.head(2)
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    EU_Sales  JP_Sales  Other_Sales  ...    0.1   0.09   0.08   0.07   0.06  \
# 0     29.02      3.77         8.46  ...  82.74  82.74  82.74  82.74  82.74
# 1      3.58      6.81         0.77  ...  82.74  82.74  82.74  82.74  82.74
#
#     0.05   0.04   0.03   0.02   0.01
# 0  82.74  82.74  82.74  82.74  82.74
# 1  82.74  82.74  82.74  82.74  82.74
#
# [2 rows x 634 columns]

# %%
data.rename(columns = {'Name' : 'Game Name'})
# Out:
#         Rank                                         Game Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.head(2)
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    EU_Sales  JP_Sales  Other_Sales  ...    0.1   0.09   0.08   0.07   0.06  \
# 0     29.02      3.77         8.46  ...  82.74  82.74  82.74  82.74  82.74
# 1      3.58      6.81         0.77  ...  82.74  82.74  82.74  82.74  82.74
#
#     0.05   0.04   0.03   0.02   0.01
# 0  82.74  82.74  82.74  82.74  82.74
# 1  82.74  82.74  82.74  82.74  82.74
#
# [2 rows x 634 columns]

# %%
data.EU_Sales.mean() #mean of eu_sales
# Out:
# 0.1466520062658483

# %%
#standard deviation of NA_sales
data.JP_Sales.std()
# Out:
# 0.30929064808213236

# %%
data.head(2)
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    EU_Sales  JP_Sales  Other_Sales  ...    0.1   0.09   0.08   0.07   0.06  \
# 0     29.02      3.77         8.46  ...  82.74  82.74  82.74  82.74  82.74
# 1      3.58      6.81         0.77  ...  82.74  82.74  82.74  82.74  82.74
#
#     0.05   0.04   0.03   0.02   0.01
# 0  82.74  82.74  82.74  82.74  82.74
# 1  82.74  82.74  82.74  82.74  82.74
#
# [2 rows x 634 columns]

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    Global_Sales  82.74  40.24  35.82  ...    0.1   0.09   0.08   0.07   0.06  \
# 0         82.74  82.74  82.74  82.74  ...  82.74  82.74  82.74  82.74  82.74
# 1         40.24  82.74  82.74  82.74  ...  82.74  82.74  82.74  82.74  82.74
# 2         35.82  82.74  82.74  82.74  ...  82.74  82.74  82.74  82.74  82.74
# 3         33.00  82.74  82.74  82.74  ...  82.74  82.74  82.74  82.74  82.74
# 4         31.37  82.74  82.74  82.74  ...  82.74  82.74  82.74  82.74  82.74
#
#     0.05   0.04   0.03   0.02   0.01
# ...

# %%
data.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  Global_Sales  82.74  40.24  35.82  ...  \
# 16593  2002.0  Platform       Kemco          0.01  82.74  82.74  82.74  ...
# 16594  2003.0   Shooter  Infogrames          0.01  82.74  82.74  82.74  ...
# 16595  2008.0    Racing  Activision          0.01  82.74  82.74  82.74  ...
# 16596  2010.0    Puzzle    7G//AMES          0.01  82.74  82.74  82.74  ...
# 16597  2003.0  Platform     Wanadoo          0.01  82.74  82.74  82.74  ...
#
#          0.1   0.09   0.08   0.07   0.06   0.05   0.04   0.03   0.02   0.01
# ...

# %%
sn.countplot(x ='Global_Sales', data = data)
plt.title("Top Global Sales Movies")
plt.xticks(rotation=45)
plt.show()
