# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import constants

# %%
pollution = pd.read_csv(r"C:\Users\prade\OneDrive\Desktop\Data Visualization\polluted_countries_cities.csv")

# %%
pollution
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# ...

# %%
pollution.head()
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
# 2           2         3   India       Gaya  2016    149        50% -< 75%
# 3           3         4   India   Varanasi  2016    146              >75%
# 4           4         5   India      Patna  2016    144              >75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018
# 2   275                 NaN                     2018
# 3   260                 NaN                     2018
# 4   266                 NaN                     2018

# %%
pollution.tail()
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 495              >75%    31                >75%                     2018
# 496              >75%    29                >75%                     2018
# 497              >75%    35                >75%                     2018
# 498        50% -< 75%    59                 NaN                     2018
# 499              >75%    56                >75%                     2018

# %%
pollution.isnull
# Out:
# <bound method DataFrame.isnull of      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# ...

# %%
pollution.isnull().any(axis=1)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 495    False
# 496    False
# 497    False
# 498     True
# 499    False
# Length: 500, dtype: bool

# %%
rows_missing_values = pollution.isnull().any(axis=1)
pollution[rows_missing_values]
# Out:
#      Unnamed: 0  Position            Country          City/Town  Year  PM2.5  \
# 0             0         1              India             Kanpur  2016    173
# 1             1         2              India          Faridabad  2016    172
# 2             2         3              India               Gaya  2016    149
# 3             3         4              India           Varanasi  2016    146
# 4             4         5              India              Patna  2016    144
# ..          ...       ...                ...                ...   ...    ...
# 485         485       486               Iran      Pol-e Dokhtar  2016     27
# 486         486       487             Israel          Bnei Brak  2015     27
# 490         490       491  Republic of Korea  Chungcheongnam-Do  2016     27
# 491         491       492  Republic of Korea   Gyeongsangbuk-Do  2016     27
# 498         498       499        El Salvador       San Salvador  2016     27
#
# ...

# %%
pollution
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10  Database version (year)
# 0                >75%   319                     2018
# 1                >75%   316                     2018
# ...

# %%
pollution = pollution.drop(columns=['Unnamed: 0', 'Temporal coverage', 'Database version (year)'])

# %%
pollution
# Out:
#      Position      Country     City/Town  Year  PM2.5  PM10
# 0           1        India        Kanpur  2016    173   319
# 1           2        India     Faridabad  2016    172   316
# 2           3        India          Gaya  2016    149   275
# 3           4        India      Varanasi  2016    146   260
# 4           5        India         Patna  2016    144   266
# ..        ...          ...           ...   ...    ...   ...
# 495       496       Poland        Lublin  2016     27    31
# 496       497       Poland       Siedlce  2016     27    29
# 497       498       Poland     Trzebinia  2016     27    35
# 498       499  El Salvador  San Salvador  2016     27    59
# 499       500       Turkey         Sivas  2016     27    56
#
# [500 rows x 6 columns]

# %%
pollution = pollution.sort_values(by=['PM2.5'], ascending = Fales).head(20)

# %%
pollution.tail(20)
# Out:
#    Position   Country  City/Town  Year  PM2.5  PM10
# 9        10     India    Gurgaon  2016    120   124
# 8         9     India       Agra  2016    131   194
# 7         8  Cameroon    Bamenda  2012    132   141
# 6         7     India    Lucknow  2016    138   255
# 5         6     India      Delhi  2016    143   292
# 4         5     India      Patna  2016    144   266
# 3         4     India   Varanasi  2016    146   260
# 2         3     India       Gaya  2016    149   275
# 1         2     India  Faridabad  2016    172   316
# 0         1     India     Kanpur  2016    173   319

# %%
pollution
# Out:
#    Position   Country  City/Town  Year  PM2.5  PM10
# 9        10     India    Gurgaon  2016    120   124
# 8         9     India       Agra  2016    131   194
# 7         8  Cameroon    Bamenda  2012    132   141
# 6         7     India    Lucknow  2016    138   255
# 5         6     India      Delhi  2016    143   292
# 4         5     India      Patna  2016    144   266
# 3         4     India   Varanasi  2016    146   260
# 2         3     India       Gaya  2016    149   275
# 1         2     India  Faridabad  2016    172   316
# 0         1     India     Kanpur  2016    173   319

# %%
pollution
# Out:
#    Position   Country  City/Town  Year  PM2.5  PM10
# 9        10     India    Gurgaon  2016    120   124
# 8         9     India       Agra  2016    131   194
# 7         8  Cameroon    Bamenda  2012    132   141
# 6         7     India    Lucknow  2016    138   255
# 5         6     India      Delhi  2016    143   292
# 4         5     India      Patna  2016    144   266
# 3         4     India   Varanasi  2016    146   260
# 2         3     India       Gaya  2016    149   275
# 1         2     India  Faridabad  2016    172   316
# 0         1     India     Kanpur  2016    173   319

# %%
pollution
# Out:
#    Position   Country  City/Town  Year  PM2.5  PM10
# 9        10     India    Gurgaon  2016    120   124
# 8         9     India       Agra  2016    131   194
# 7         8  Cameroon    Bamenda  2012    132   141
# 6         7     India    Lucknow  2016    138   255
# 5         6     India      Delhi  2016    143   292
# 4         5     India      Patna  2016    144   266
# 3         4     India   Varanasi  2016    146   260
# 2         3     India       Gaya  2016    149   275
# 1         2     India  Faridabad  2016    172   316
# 0         1     India     Kanpur  2016    173   319

# %%
pollution.tail()
# Out:
#    Position   Country City/Town  Year  PM2.5  PM10
# 5         6     India     Delhi  2016    143   292
# 6         7     India   Lucknow  2016    138   255
# 7         8  Cameroon   Bamenda  2012    132   141
# 8         9     India      Agra  2016    131   194
# 9        10     India   Gurgaon  2016    120   124

# %%
pollution
# Out:
#    Position   Country  City/Town  Year  PM2.5  PM10
# 9        10     India    Gurgaon  2016    120   124
# 8         9     India       Agra  2016    131   194
# 7         8  Cameroon    Bamenda  2012    132   141
# 6         7     India    Lucknow  2016    138   255
# 5         6     India      Delhi  2016    143   292
# 4         5     India      Patna  2016    144   266
# 3         4     India   Varanasi  2016    146   260
# 2         3     India       Gaya  2016    149   275
# 1         2     India  Faridabad  2016    172   316
# 0         1     India     Kanpur  2016    173   319

# %%
pollution = pollution.sort_values(by=['PM2.5'], ascending = False).head(20)

# %%
pollution.head(20)
# Out:
#    Position   Country  City/Town  Year  PM2.5  PM10
# 0         1     India     Kanpur  2016    173   319
# 1         2     India  Faridabad  2016    172   316
# 2         3     India       Gaya  2016    149   275
# 3         4     India   Varanasi  2016    146   260
# 4         5     India      Patna  2016    144   266
# 5         6     India      Delhi  2016    143   292
# 6         7     India    Lucknow  2016    138   255
# 7         8  Cameroon    Bamenda  2012    132   141
# 8         9     India       Agra  2016    131   194
# 9        10     India    Gurgaon  2016    120   124

# %%
print(pollution.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Position   10 non-null     int64
#  1   Country    10 non-null     object
#  2   City/Town  10 non-null     object
#  3   Year       10 non-null     int64
#  4   PM2.5      10 non-null     int64
#  5   PM10       10 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 560.0+ bytes
# None

# %%
pollution = pd.read_csv(r"C:\Users\prade\OneDrive\Desktop\Data Visualization\polluted_countries_cities.csv")

# %%
pollution
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# ...

# %%
pollution = pollution.drop(columns=['Unnamed: 0', 'Temporal coverage', 'Database version (year)'])

# %%
pollution
# Out:
#      Position      Country     City/Town  Year  PM2.5  PM10  \
# 0           1        India        Kanpur  2016    173   319
# 1           2        India     Faridabad  2016    172   316
# 2           3        India          Gaya  2016    149   275
# 3           4        India      Varanasi  2016    146   260
# 4           5        India         Patna  2016    144   266
# ..        ...          ...           ...   ...    ...   ...
# 495       496       Poland        Lublin  2016     27    31
# 496       497       Poland       Siedlce  2016     27    29
# 497       498       Poland     Trzebinia  2016     27    35
# 498       499  El Salvador  San Salvador  2016     27    59
# 499       500       Turkey         Sivas  2016     27    56
#
#     Temporal coverage.1
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 495                >75%
# 496                >75%
# ...

# %%
pollution = pollution.drop(columns=['Temporal coverage.1'])

# %%
pollution
# Out:
#      Position      Country     City/Town  Year  PM2.5  PM10
# 0           1        India        Kanpur  2016    173   319
# 1           2        India     Faridabad  2016    172   316
# 2           3        India          Gaya  2016    149   275
# 3           4        India      Varanasi  2016    146   260
# 4           5        India         Patna  2016    144   266
# ..        ...          ...           ...   ...    ...   ...
# 495       496       Poland        Lublin  2016     27    31
# 496       497       Poland       Siedlce  2016     27    29
# 497       498       Poland     Trzebinia  2016     27    35
# 498       499  El Salvador  San Salvador  2016     27    59
# 499       500       Turkey         Sivas  2016     27    56
#
# [500 rows x 6 columns]

# %%
pollution.head(20)
# Out:
#     Position     Country    City/Town  Year  PM2.5  PM10
# 0          1       India       Kanpur  2016    173   319
# 1          2       India    Faridabad  2016    172   316
# 2          3       India         Gaya  2016    149   275
# 3          4       India     Varanasi  2016    146   260
# 4          5       India        Patna  2016    144   266
# 5          6       India        Delhi  2016    143   292
# 6          7       India      Lucknow  2016    138   255
# 7          8    Cameroon      Bamenda  2012    132   141
# 8          9       India         Agra  2016    131   194
# 9         10       India      Gurgaon  2016    120   124
# 10        11       India  Muzaffarpur  2016    120   221
# 11        12    Pakistan     Peshawar  2010    111   540
# 12        13    Pakistan   Rawalpindi  2010    107   448
# 13        14       India       Jaipur  2016    105   193
# 14        15      Uganda      Kampala  2013    104   170
# ...

# %%
 pollution = pollution.sort_values(by=['Year'], ascending = False)

# %%
pollution
# Out:
#      Position                 Country     City/Town  Year  PM2.5  PM10
# 50         51            Saudi Arabia         Yanbu  2017     75   116
# 0           1                   India        Kanpur  2016    173   319
# 302       303                   China         Wuwei  2016     39    97
# 314       315                   China       Zhangye  2016     38    90
# 313       314                   China       Wenzhou  2016     38    81
# ..        ...                     ...           ...   ...    ...   ...
# 74         75                Pakistan        Lahore  2010     68   198
# 85         86  Bosnia and Herzegovina         Tuzla  2010     65   106
# 23         24                Pakistan       Karachi  2009     88   290
# 444       445                 Morocco        Meknes  2008     29    47
# 326       327              Madagascar  Antananarivo  2008     37    60
#
# [500 rows x 6 columns]

# %%
pollution.head(20)
# Out:
#      Position       Country    City/Town  Year  PM2.5  PM10
# 50         51  Saudi Arabia        Yanbu  2017     75   116
# 0           1         India       Kanpur  2016    173   319
# 302       303         China        Wuwei  2016     39    97
# 314       315         China      Zhangye  2016     38    90
# 313       314         China      Wenzhou  2016     38    81
# 311       312         China      Guigang  2016     38    55
# 310       311         China       Gannan  2016     38    70
# 309       310         China       Foshan  2016     38    55
# 308       309        Turkey       Amasya  2016     39    57
# 307       308          Peru         Lima  2016     39    58
# 306       307          Iran  Shahinshahr  2016     39    89
# 305       306         India      Solapur  2016     39    71
# 304       305         China     Zhaoyang  2016     39    69
# 303       304         China       Yantai  2016     39    76
# 301       302         China     Shangluo  2016     39    72
# ...

# %%
 pollution = pollution.sort_values(by=['PM2.5'], ascending = False)

# %%
pollution.head(10)
# Out:
#    Position   Country  City/Town  Year  PM2.5  PM10
# 0         1     India     Kanpur  2016    173   319
# 1         2     India  Faridabad  2016    172   316
# 2         3     India       Gaya  2016    149   275
# 3         4     India   Varanasi  2016    146   260
# 4         5     India      Patna  2016    144   266
# 5         6     India      Delhi  2016    143   292
# 6         7     India    Lucknow  2016    138   255
# 7         8  Cameroon    Bamenda  2012    132   141
# 8         9     India       Agra  2016    131   194
# 9        10     India    Gurgaon  2016    120   124

# %%
sn.countplot(x ='Country', data = pollution)
plt.title("Countries With Top 25 Highest PM2.5 Polluted Cities")
plt.xticks(rotation=45)
plt.show()

# %%
sn.pairplot(pollution)
plt.show()

# %%
plt.scatter(x = pollution['Country'], y = pollution['PM2.5'], s = 5)
plt.xlabel('Country')
plt.ylabel('PM2.5')
plt.title("Countries With Top 25 Highest PM2.5 Polluted Cities")

plt.show()

# %%
polluti
# Out:
#    Position   Country  City/Town  Year  PM2.5  PM10
# 0         1     India     Kanpur  2016    173   319
# 1         2     India  Faridabad  2016    172   316
# 2         3     India       Gaya  2016    149   275
# 3         4     India   Varanasi  2016    146   260
# 4         5     India      Patna  2016    144   266
# 5         6     India      Delhi  2016    143   292
# 6         7     India    Lucknow  2016    138   255
# 7         8  Cameroon    Bamenda  2012    132   141
# 8         9     India       Agra  2016    131   194
# 9        10     India    Gurgaon  2016    120   124

# %%
plt.scatter(x = pollution['Country'], y = pollution['PM2.5'], s = 5)
plt.xlabel('Country')
plt.ylabel('PM2.5')
plt.title("Countries With Top 25 Highest PM2.5 Polluted Cities")

plt.show()

# %%
pollution.head()
# Out:
#    Position Country  City/Town  Year  PM2.5  PM10
# 0         1   India     Kanpur  2016    173   319
# 1         2   India  Faridabad  2016    172   316
# 2         3   India       Gaya  2016    149   275
# 3         4   India   Varanasi  2016    146   260
# 4         5   India      Patna  2016    144   266

# %%
sn.countplot(x = pollution['Country'])
plt.title("Countries with Top 20 PM10 polluted cities")
plt.xticks(rotation=45)
plt.show()

# %%
top_20_cities = top_20_pm_25['City/Town'].values
print(top_20_cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [127], in <cell line: 1>()
# ----> 1 top_20_cities = top_20_pm_25['City/Town'].values
#       2 print(top_20_cities)
#
# NameError: name 'top_20_pm_25' is not defined

# %%
top_25_country = pollution.sort_values(by=['PM2.5'], ascending = False).head(25)

# %%
top_25_country
# Out:
#     Position     Country     City/Town  Year  PM2.5  PM10
# 0          1       India        Kanpur  2016    173   319
# 1          2       India     Faridabad  2016    172   316
# 2          3       India          Gaya  2016    149   275
# 3          4       India      Varanasi  2016    146   260
# 4          5       India         Patna  2016    144   266
# 5          6       India         Delhi  2016    143   292
# 6          7       India       Lucknow  2016    138   255
# 7          8    Cameroon       Bamenda  2012    132   141
# 8          9       India          Agra  2016    131   194
# 9         10       India       Gurgaon  2016    120   124
# 10        11       India   Muzaffarpur  2016    120   221
# 11        12    Pakistan      Peshawar  2010    111   540
# 12        13    Pakistan    Rawalpindi  2010    107   448
# 13        14       India        Jaipur  2016    105   193
# 14        15      Uganda       Kampala  2013    104   170
# ...

# %%
sn.countplot(x =top_25_country['Country'])
plt.title("Countries with Top 25 PM2.5 polluted cities")
plt.xticks(rotation=60)
plt.show()

# %%
top_25_cities = top_25_country['City/Town'].values
print(top_25_cities)
# Out:
# ['Kanpur' 'Faridabad' 'Gaya' 'Varanasi' 'Patna' 'Delhi' 'Lucknow'
#  'Bamenda' 'Agra' 'Gurgaon' 'Muzaffarpur' 'Peshawar' 'Rawalpindi' 'Jaipur'
#  'Kampala' 'Patiala' 'Jodhpur' 'Narayanganj' 'Baoding' 'Doha'
#  'Ulaanbaatar' 'Jinan' 'Shijiazhuang' 'Karachi' 'Hengshui']

# %%
sn.pairplot(pollution)
plt.show()

# %%
sn.heatmap(pollution.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(x = top_25_country['Country'], y = top_25_country['PM2.5'], s = 10)
plt.xlabel('Country')
plt.ylabel('PM2.5')
plt.title("Countries With Top 25 Highest PM2.5 Polluted Cities")
plt.xticks(rotation=45)


plt.show()
